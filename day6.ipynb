# %% [markdown]
# ### Advanced Selection Methods

# %%
import geopandas as gpd

world_gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
boundary = world_gdf.boundary
boundary.plot()

world_gdf
#world_gdf.plot()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_6024\799609772.py:3: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# ..           ...            ...                       ...    ...         ...
# 172    6944975.0         Europe                    Serbia    SRB       51475
# ...

# %%
africa_countries_df = world_gdf[world_gdf['continent'] == 'Africa']
africa_countries_df.plot()
# Out:
# <Axes: >

# %%
### countries in africa with population greater than 10000000 and starts with N

africa_subset = world_gdf[
    (world_gdf['continent'] == 'Africa') &
    (world_gdf['pop_est'] > 10000000) &
    (world_gdf['name'].str.contains('N', case=False))
]

africa_subset.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
### Adding a population column

import numpy as np

africa_subset
population = np.random.randint(10000000, 50000000, size=18)

africa_subset['population'] = population

africa_subset
# Out:
# c:\Users\Owner\anaconda3\envs\geo_python\Lib\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#          pop_est continent             name iso_a3  gdp_md_est  \
# 1     58005463.0    Africa         Tanzania    TZA       63177
# 11    86790567.0    Africa  Dem. Rep. Congo    COD       50400
# 13    52573973.0    Africa            Kenya    KEN       95503
# 14    42813238.0    Africa            Sudan    SDN       30513
# 51    16296364.0    Africa          Senegal    SEN       23578
# 54    11801151.0    Africa            Benin    BEN       14390
# 55    23310715.0    Africa            Niger    NER       12911
# ...

# %% [markdown]
# ### Geometric Operations with Geopandas

# %% [markdown]
# #### Dissolve

# %%
world_gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

world_gdf_dissolved = world_gdf.dissolve(by='continent')
world_gdf.explore()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_6024\2697130720.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...

# %% [markdown]
# #### Clip

# %%
world_cities_gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
#world_cities_gdf.plot()

# getting the african boundaries
africa = world_gdf[world_gdf['continent'] == 'Africa']

# performing the clip operation
africa_cities = world_cities_gdf.clip(africa)

africa_cities.plot()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_6024\301296719.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_cities' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_cities_gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
# <Axes: >

# %% [markdown]
# ### Buffer

# %%
world_cities_gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
#world_cities_gdf.plot()

# getting the african boundaries
africa = world_gdf[
    (world_gdf['continent'] == 'Africa') &
    (world_gdf['name'].str.contains("N"))
    ]

# performing the clip operation
africa_cities = world_cities_gdf.clip(africa)

africa_buffer = africa_cities.buffer(1)

africa_buffer.plot(figsize=(9,6), alpha=0.5)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_6024\1147719664.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_cities' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_cities_gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
# C:\Users\Owner\AppData\Local\Temp\ipykernel_6024\1147719664.py:13: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   africa_buffer = africa_cities.buffer(1)
# <Axes: >

# %% [markdown]
# ### Plotting with Geopandas

# %%
world_cities_gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
#world_cities_gdf.plot()

# getting the african boundaries
africa = world_gdf[
    (world_gdf['continent'] == 'Africa') 
    ]

# performing the clip operation
africa_cities = world_cities_gdf.clip(africa)

base = africa.plot(
    figsize= (16,24),
    column='name',
    legend=True,
    cmap='Paired',
    legend_kwds= {
        'title': "African countries",
        'shadow': True,
        'ncols': 3,
        'loc': 'lower left'
    },
    zorder=1
)

# # Add buffer
# africa_buffer = africa_cities.buffer(1)
# africa_buffer.plot(ax=base, alpha=0.5, zorder=3 )

# Add africa cities layer
africa_cities.plot(ax=base, color='black' , zorder=4)

africa.boundary.plot(ax=base, zorder=2)
# base.set_axis_off()
base.grid(animated=True)


base.set_title('CITIES IN AFRICA', fontsize=25, fontweight=3)
# africa_buffer.plot(figsize=(9,6), alpha=0.5)

# Label the cities
for idx, row in africa_cities.iterrows():
    base.text(row.geometry.x, row.geometry.y, row['name'], fontsize=8, color='black', fontweight=2,
            ha='right', va='center', zorder=6)

# Label the countries
# for idx, row in africa.iterrows():
#     # Using the centroid of each country for labeling
#     base.text(row.geometry.centroid.x, row.geometry.centroid.y, row['name'], fontsize=9, color='blue',
#             ha='center', va='center', zorder=6, fontweight='bold')
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_6024\30734032.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_cities' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_cities_gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
